# %%
if "ata" in "data science":
    print(1)
# Out:
# 1

# %%
import PyPDF2

# %%
pdfFileObj=open(r"D:\Users\abhisv\Desktop\MyPath (201810310712337059310 ).pdf","rb")

# %%
pdfReader=PyPDF2.PdfFileReader(pdfFileObj)
pageObj=pdfReader.getPage(1)
print(pageObj.extractText())
# Out:
# Performance Review 201820Employee Mid-Year Assessment:Reviewer Mid-Year Assessment:Employee Year-End Assessment:1) Attended virtual training's on ODI Advanced concepts and    OBIA/ODI customization.2) Attended lot many internal training's in project.3) Gaining the knowledge in other advanced technologies like Data science and python.4) I have always maintained 100 % compliance for organization and Client polices, guidelines,process and time-sheet entry.5) Demonstrating discipline in adherence to company norms such as wearing of ID card in office,timely submission of Time Sheets.6) Plan leaves at least 30 days prior for self and adhere to other policies / processes as applicable.Personal ARVEDescription:#95%Weighting:50Employee Mid-Year Assessment:Reviewer Mid-Year Assessment:Employee Year-End Assessment:1) I have always maintained 100 % compliance for organization and Client polices, guidelines,process and time-sheet entry.2) Attended all training's which was assigned to me.Individua
# ...

# %%
pdfFileObj=open(r"D:\Learning Python, 5th Edition.pdf","rb")

# %%
pdfReader=PyPDF2.PdfFileReader(pdfFileObj)

# %%
pdfReader.numPages
# Out:
# 1594

# %%
pdfReader=PyPDF2.PdfFileReader(pdfFileObj)
text=""
for i in range(0,200):
    pageObj=pdfReader.getPage(i)
    if 'Test Your Knowledge' in pageObj.extractText():
        print(i,len(pageObj.extractText().split()))
        print(pageObj.extractText())
# Out:
# 74 15
#
#
#
#
# Test Your Knowledge: Quiz
#
#
#
#
#
#
#
#
#
#
#
# import this
#
# Test Your Knowledge: Answers
#
#
#
#
#
#
#
#
#
#
# Test Your Knowledge: Answers|23
# www.it-ebooks.info
# 76 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Test Your Knowledge: Answers|25
# www.it-ebooks.info
# 92 13
# Test Your Knowledge: Quiz
#
#
#
#
#
#
# Test Your Knowledge: Answers
#
#
#
#
#
#
#
#
#
#
# Test Your Knowledge: Answers|41
# www.it-ebooks.info
# 136 12
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chapter Summary
#
#
# exec
#
#
#
#
#
#
#
#
#
# Test Your Knowledge: Quiz
#
#
#
#
#
#
#
# Test Your Knowledge: Quiz|85
# www.it-ebooks.info
# 137 18
# Test Your Knowledge: Answers
#
#
#
# python
#
#
#
# PATH
# cd
#
# python
# C:\Python33\python
#
#
#
#
#
#
# exec
#
#
#
# #!
#
#
#
#
#
#
#
# input
#
#
#
#
#
#
#
#
#
#
# 86|Chapter 3:
# How You Run Programswww.it-ebooks.info
# 138 21
#
#
#
#
#
#
#
#
#
#
# Test Your Knowledge: Part I Exercises
#
#
#
#
#
#
#
# >>>
#
# "Hello World!"
#
#
# cd
#
# PATHPATH
#
# ...

# %%
#api

# %%
import requests

# %%
api_address='http://samples.openweathermap.org/data/2.5/weather?appid=b6907d289e10d714a6e88b30761fae22&q='

# %%
city=input('City Name :')
url=api_address+city
json_data=requests.get(url).json()
# Out:
# City Name :bangalore

# %%
json_data
# Out:
# {'coord': {'lon': -0.13, 'lat': 51.51},
#  'weather': [{'id': 300,
#    'main': 'Drizzle',
#    'description': 'light intensity drizzle',
#    'icon': '09d'}],
#  'base': 'stations',
#  'main': {'temp': 280.32,
#   'pressure': 1012,
#   'humidity': 81,
#   'temp_min': 279.15,
#   'temp_max': 281.15},
#  'visibility': 10000,
#  'wind': {'speed': 4.1, 'deg': 80},
#  'clouds': {'all': 90},
#  'dt': 1485789600,
#  'sys': {'type': 1,
#   'id': 5091,
#   'message': 0.0103,
#   'country': 'GB',
#   'sunrise': 1485762037,
#   'sunset': 1485794875},
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
import docx

# %%
from docx import Document
doc=docx.Document("C:\\Users\\abhisv.CORP\\3D Objects\\083850_2019.docx")
y=[]
for i in doc.paragraphs:
    y.append(i.text)

# %%
y
# Out:
# ['Capgemini Technology Services India Limited',
#  'No.14, Rajiv Gandhi Infotech Park, Hinjawadi Phase III,',
#  'MIDC - SEZ, Village Man, Taluka Mulshi,',
#  'Pune- 411 057, Maharashtra, India',
#  'Tel: +91.20.6699 1000 | Fax: +91.20.6699 5050',
#  'www.in.capgemini.com',
#  'April 14, 2019',
#  '',
#  'Name: SV,Abhishek',
#  '',
#  'Emp ID: 083850',
#  '',
#  '',
#  'Dear Abhishek,',
#  '',
#  '',
#  'Overall 2018 has been a robust performance year for Capgemini. We appreciate your dedication and energy that helped the organization achieve its business objectives and would look forward to your commitment and optimism in the coming years too.',
#  '',
#  'We are also glad to share with you that your revised compensation for 2019 effective April 1, 2019 is as below:',
#  '',
#  '',
#  '',
#  'A break-up of your revised compensation is detailed in the Salary Annexure.',
#  '',
#  'Congratulations and wishing you a happy and rewarding career with Capgemini!',
#  '',
#  '',
# ...
