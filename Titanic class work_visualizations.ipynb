# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\abhisv.CORP\3D Objects\train.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
plt.figure(figsize=(4,4))
sns.distplot(df[df.columns[5]].astype(int),kde=False,color='r')

# %%
## The actual people travelled with the age 30 are 70(which is (70/250)*100 ), but as we replaced the null values with the median, 
##so we are able to get nearly 250 people.

# %%
## 5% of the people with the age group of 1-10 are travelled in titanic.
## 70% of people are belong to age group of 20 to 30

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
sns.countplot(df['Sex'])

# %%
sns.jointplot(df['Age'],df['Fare'],kind='reg')

# %%
##there is a minimal correlation between age and fare.
## majority of the ppl who are spending more lies in the area 20 to 55.

# %%
sns.boxplot(df['Sex'],df['Age'],hue=df['Survived'])

# %%
sns.swarmplot(df['Pclass'],df['Age'],hue=df['Survived'])## for horizontal graphs use orient='h'

# %%
sns.heatmap(df.corr(),annot=True,cmap='magma',linewidth=4,linecolor='w')

# %%
##Pclass and fare
##Pclass and survived
##Pclass and age

# %%
plt.figure(figsize=(10,10))
sns.boxplot(df['Sex'],df['Fare'])

# %%
sns.pairplot(df.sample(100))
