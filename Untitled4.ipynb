# %%
import pandas as pd
df1=pd.read_excel(r"D:\Users\abhisv\Downloads\Assignment - 1.xlsx")

# %%
df1.head()
# Out:
#         Date Country Advertiser Account    Spends
# 0 2020-12-19     USA             9a9b24  119090.0
# 1 2020-12-20     USA             9a9b24  112809.0
# 2 2020-12-26     USA             9a9b24  101680.0
# 3 2020-12-13     USA             9a9b24  106725.0
# 4 2020-12-12     USA             9a9b24   92708.0

# %%
df1.shape
# Out:
# (7710, 4)

# %%
df2=pd.read_excel(r"D:\Users\abhisv\Music\Book1.xlsx")

# %%
df2.head()
# Out:
#           Country Region
# 0             USA    NaN
# 1          Canada    NaN
# 2           Spain     EU
# 3  United Kingdom     EU
# 4           India   APAC

# %%
pd.merge(df1,df2,how='inner',on='Country')
# Out:
#            Date Country Advertiser Account         Spends Region
# 0    2020-12-19     USA             9a9b24  119090.000000    NaN
# 1    2020-12-20     USA             9a9b24  112809.000000    NaN
# 2    2020-12-26     USA             9a9b24  101680.000000    NaN
# 3    2020-12-13     USA             9a9b24  106725.000000    NaN
# 4    2020-12-12     USA             9a9b24   92708.000000    NaN
# 5    2020-12-23     USA             9a9b24  119274.000000    NaN
# 6    2020-12-24     USA             9a9b24   94555.000000    NaN
# 7    2020-12-18     USA             9a9b24   97319.000000    NaN
# 8    2020-12-22     USA             9a9b24   99249.000000    NaN
# 9    2020-12-06     USA             9a9b24   90514.000000    NaN
# 10   2020-12-25     USA             9a9b24  114825.000000    NaN
# 11   2020-12-21     USA             9a9b24   88190.000000    NaN
# 12   2020-12-16     USA             9a9b24   98288.000000    NaN
# ...
